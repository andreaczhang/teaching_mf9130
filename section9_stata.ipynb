# %% [markdown]
# # Introduction to STATA
#
# ## Get started
#
# Useful resources:
#
# - [STATA tutorial](https://www.lse.ac.uk/Methodology/Software-tutorials/Stata-tutorials) by LSE
#
# Menu system and dialogue boxes: point and click
#
# Command window
#
# Do-file editor
#
#
# ### File system: where things are
#
#
# ### Get help
#
# In the command, type `help browse` to open up the documentation
#
#
# ## Data import, entry and manipulation
#
# Data format: `data.dta`
#
#
#
# ### Import data
#
# Inspect the data: either `browse`, or click the icon
#
# Inspect a few variables: `browse age eth` to select `age` and `eth` variables
#
# `codebook age` to inspect `age` variable
#
# Use `clear` to remove data object
#
#
# ### Enter data manually
#
# Use data editor
#
#
# ### Basic manipulation
#
#
# ```{text}
# rename var1 name
# ```
